# %%
import os
import re
import pandas as pd
from lxml import etree
from glob import glob
from pathlib import Path

# %%
folder = Path("data/nyt_xml_test")
xml_files = list(folder.glob("*.xml"))

# %%
#TEST
sample_file = xml_files[1]
print(f"Reading {sample_file}")

tree = etree.parse(sample_file)
root = tree.getroot()
# Out:
# Reading data/nyt_xml_test/91676921.xml

# %%
def clean_whitespace(s: str) -> str:
    if s is None:
        return ""
    s = re.sub(r'\s+', ' ', s)
    return s.strip()

# %%
#TEST
texts = []
for block in root.findall(".//FullText"):  
    texts.append(block.text)

article_text = "\n".join([t for t in texts if t])
print(article_text[:5000])  # first 5k chars
# Out:
#                                                                                                 AFFAIRS AT .                 The Doings of the Rebel Raiders There  How They Came and Saw and Conquered  The Property Destroyed by Them, &c.                 , Monday, Oct. 13, 1862.                 On Friday afternoon last, a dispatch was received by the telegraph operator here, from Greencastle, stating that information reached there that about 3,000 rebel cavalry had passed through Mercersburgh, and were going in the direction of Chambersburgh. This information was not made public, or the reason that it was not credited.                 ing, about 5 o clock, an express rider came in from St, Thomas, a village seven miles west from here, who said they had reached that place, had torn down the flak and chased him within three miles of Chambersburgh. Shortly after, other riders came in, confirming this statement. Our people were ails incredulous, but to do wh^t we could, the Court-house bell was rung, and the Horue Guards, about one hundred in all, turned out. About 7 o clock, some fifteen cavalry rode into the public square, with a white handkerchief on a stick, and demanded an interview with the authorities of the town, to whom they communicated the  of Gee.  for the surrender of the town, accompanied witl, the information that their  way planted on the hills west of the town, and mould shell us unless their deluded was complied with in thirty minutes. Col. ;, 1'-Marshal         .L, and one or two more citizens, accompanied this squad out to see Gen. Ilestrxo.r. As they rode out Of town, they were greeted with hearty cheers fur the Ilnion.           the pre_  of the town they met Gcn. IlevtrxoN, wuo told them that he was aware of uer Wfenculess :. that he had a strop;; force, that if the ;r aou! l sttr_ render, all          .pa  property . ha re_       . 1'u the <   and chil: would be unmolested, C: en. IlesirTUx paid it was <: to the rules of ci: w..rf:tre,:tnd esi: io the  of the 5, to wur ::6ainst ;ln se. Jm!ge ICtstu>a.t.  to tLe , and frum the steps of the Court-Louse          :atwi to the citizens there assembled the teens demanded, and took the vote as to whether we would accept them or attempt resistance. In vie:v of our  coti_ dition  so large a force, thu vote was nearly t;          iu:          , In :           ) twt:711ra  -                 utes from this, the bugle was heard in our streets, and from fifteen hundred to two thousand cavalry rode Quietly into town, threw pickets out in all directions, entered the telegraph office  after the operator had fled, paroled all the sick and wounded soldiers in the hospitals-probably about two hundred.                 Wtth the exception of an occasional cheer for Jsrs. DAVIA, and the song of " Diaie" and " My Diaryland," the best of order was observed. At 11 o clock at night, nearly all had left town, and taken positions outside, others scouring the country for miles, bringing in horses. An officer called at the bank, and demanded the specie. He was told by the cashier that it had Deen removed. To satisfy him he wss shown through the vault of the bank. Satisfied that it was so, he left after placing a guard around the building, which guarded it from further intrusion during their atay  In one instance they succeeded by threats to have a shoe stare opened, taking about one hundred dollars  worth of boots and shoes, offering Confederate money in payment. This being refused, they left, taking with them what they wanted. Attempts were made in one or two other cases to break open hat and shoe stores, but the men so violating the terms of surrender were promptly ordered under arrest. In the morning they all congregated in our streets, Dassed out the Baltimore Pike eastward, before Generals STVear and        , surrounded by their  Staffs. These officers differed but little in uniform from the privates, were very gentlemanly and unassuming, and  themselves upon the good behavior of their ...

# %%
def extract_fields_from_xml(file_path):
    try:
        tree = etree.parse(file_path)
        root = tree.getroot()
        data = {
            'pub_date': None,
            'object_type': None,
            'raw_text': None
        }

        # Extract dates
        date_element = root.find('.//NumericPubDate')
        if date_element is not None and date_element.text:
            data['pub_date'] = date_element.text.strip()
        
        # extract object types
        object_types = root.findall('.//ObjectType')
        if object_types:
            # Join all unique object types into a single string for a clean Parquet column
            unique_types = set(o.text.strip() for o in object_types if o.text)
            data['object_type'] = " | ".join(sorted(list(unique_types)))
        
        # extract article text
        text_element = root.find('.//FullText')
        if text_element is not None and text_element.text:
            raw_text = text_element.text
            # strip extra whitespace
            data['raw_text'] = clean_whitespace(raw_text)

        # Check for mandatory fields before returning
        if not data['pub_date'] or not data['raw_text']:
            # Skip records missing essential data
            print(f"Warning: Skipping {file_path} due to missing date or text.")
            return None
        
        return data

    except Exception as e:
        print(f"Error processing file {file_path}: {e}")
        return None

# %%
def main_processing(xml_directory, output_parquet_file):
    all_xml_files = glob(os.path.join(xml_directory, '*.xml')) 
    print(f"Found {len(all_xml_files)} XML files to process.")
    
    # List to hold the extracted records
    records = []
    
    for i, file_path in enumerate(all_xml_files):
        record = extract_fields_from_xml(file_path)
        if record:
            records.append(record)
        
        if (i + 1) % 1000 == 0:
            print(f"Processed {i + 1} files...")

    # Convert list of records to a DataFrame
    df = pd.DataFrame(records)
    
    print(f"\nSuccessfully extracted data from {len(df)} records.")
    
    # Write the DataFrame to the highly compressed Parquet format
    # Using 'pyarrow' engine is standard for robust Parquet conversion
    df.to_parquet(output_parquet_file, engine='pyarrow', index=False, compression='snappy')
    
    print(f"Data written successfully to {output_parquet_file}")
    print(f"Final DataFrame Shape: {df.shape}")


    
main_processing("data/nyt_xml_test", "data/nyt_sample.parquet")
# Out:
# Found 25000 XML files to process.
# Processed 1000 files...
# Warning: Skipping data/nyt_xml_test/91979384.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/96604992.xml due to missing date or text.
# Processed 2000 files...
# Warning: Skipping data/nyt_xml_test/93313655.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/95171575.xml due to missing date or text.
# Processed 3000 files...
# Warning: Skipping data/nyt_xml_test/94563757.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/91854157.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/95412148.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/94442211.xml due to missing date or text.
# Processed 4000 files...
# Warning: Skipping data/nyt_xml_test/93380377.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/95160346.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/95207474.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/91792924.xml due to missing date or text.
# Processed 5000 files...
# Warning: Skipping data/nyt_xml_test/95269378.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/94661438.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/95493039.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/96178532.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/94309946.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/96635449.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/95317617.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/94219840.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/92075878.xml due to missing date or text.
# Processed 6000 files...
# Warning: Skipping data/nyt_xml_test/95012034.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/95079664.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/91902453.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/94525022.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/91666078.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/94090031.xml due to missing date or text.
# Processed 7000 files...
# Warning: Skipping data/nyt_xml_test/94338549.xml due to missing date or text.
# Processed 8000 files...
# Warning: Skipping data/nyt_xml_test/96422528.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/93949522.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/91971119.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/93999398.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/96817538.xml due to missing date or text.
# Processed 9000 files...
# Warning: Skipping data/nyt_xml_test/94619245.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/93939155.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/93924802.xml due to missing date or text.
# Processed 10000 files...
# Warning: Skipping data/nyt_xml_test/93941637.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/94103049.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/93153045.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/94507257.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/95234503.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/95223024.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/93776866.xml due to missing date or text.
# Processed 11000 files...
# Warning: Skipping data/nyt_xml_test/95228932.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/95066948.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/91716421.xml due to missing date or text.
# Processed 12000 files...
# Warning: Skipping data/nyt_xml_test/94330015.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/94150705.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/93363273.xml due to missing date or text.
# Processed 13000 files...
# Processed 14000 files...
# Warning: Skipping data/nyt_xml_test/91918407.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/95742345.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/94652064.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/95014507.xml due to missing date or text.
# Processed 15000 files...
# Warning: Skipping data/nyt_xml_test/94577857.xml due to missing date or text.
# Processed 16000 files...
# Warning: Skipping data/nyt_xml_test/93805975.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/94052358.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/95166515.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/91641922.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/91839194.xml due to missing date or text.
# Processed 17000 files...
# Warning: Skipping data/nyt_xml_test/91769312.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/93196250.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/93309695.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/91752331.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/96591162.xml due to missing date or text.
# Processed 18000 files...
# Warning: Skipping data/nyt_xml_test/94198202.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/94192023.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/91785640.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/93598808.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/91715047.xml due to missing date or text.
# Processed 19000 files...
# Warning: Skipping data/nyt_xml_test/93779547.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/93777869.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/93439589.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/95157432.xml due to missing date or text.
# Processed 20000 files...
# Warning: Skipping data/nyt_xml_test/91812768.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/94496970.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/96670648.xml due to missing date or text.
# Processed 21000 files...
# Warning: Skipping data/nyt_xml_test/95041146.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/93764070.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/92274627.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/93582819.xml due to missing date or text.
# Processed 22000 files...
# Warning: Skipping data/nyt_xml_test/94539824.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/94253268.xml due to missing date or text.
# Processed 23000 files...
# Warning: Skipping data/nyt_xml_test/93898186.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/94071763.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/95169981.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/95379839.xml due to missing date or text.
# Processed 24000 files...
# Warning: Skipping data/nyt_xml_test/95235222.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/91561801.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/95147352.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/95150349.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/93440522.xml due to missing date or text.
# Warning: Skipping data/nyt_xml_test/93820057.xml due to missing date or text.
# Processed 25000 files...
#
# Successfully extracted data from 24908 records.
# Data written successfully to data/nyt_sample.parquet
# Final DataFrame Shape: (24908, 3)

# %%
#TEST

parquet_sample = pd.read_parquet("data/nyt_sample.parquet")
print(parquet_sample.head())
print(parquet_sample.info())
print(parquet_sample.describe())
# Out:
#    pub_date                               object_type  \
# 0  18710312  Advertisement | Classified Advertisement
# 1  18621016                    Front Page/Cover Story
# 2  18850105                         Article | Feature
# 3  18810317                    Front Page/Cover Story
# 4  18791230                         Article | Feature
#
#                                             raw_text
# 0  REAL AT AUCTIOi:. AI) H. , Auctioneer. 120 CgN...
# 1  AFFAIRS AT . The Doings of the Rebel Raiders T...
# 2  AN ATTEMPT TO BREAK JAIL FAILS. CHICAGO, Jan. ...
# 3  THE IRISH RENT TROUBLES. REPORTS OF AN ATTACK ...
# 4  ARTIFICIAL DIAMONDS. A >;uropean has ma,do a <...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24908 entries, 0 to 24907
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   pub_date     24908 non-null  object
#  1   object_type  24908 non-null  object
#  2   raw_text     24908 non-null  object
# dtypes: object(3)
# memory usage: 583.9+ KB
# None
#         pub_date        object_type          raw_text
# count      24908              24908             24908
# unique     12332                 18             24849
# top     18960531  Article | Feature  NEWS OF THE DAY.
# freq          14              12933                18
